# %% [markdown]
# # COVID-19 Exploratory Data Analysis
# > (Almost) Everything You Want To Know About COVID-19.
#
# - author: Devakumar kp
# - comments: true
# - categories: [EDA]
# - permalink: /corona-eda/
# - toc: true
# - image: images/covid-eda-2-1.png

# %% [markdown]
# These visualizations were made by [Devakumar kp](https://twitter.com/imdevskp).  Original notebook is [here](https://www.kaggle.com/imdevskp/covid-19-analysis-viz-prediction-comparisons).

# %%
#hide
# essential libraries
import json
import random
from urllib.request import urlopen

# storing and anaysis
import numpy as np
import pandas as pd

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
import plotly.figure_factory as ff
import folium

# color pallette
cnf = '#393e46' # confirmed - grey
dth = '#ff2e63' # death - red
rec = '#21bf73' # recovered - cyan
act = '#fe9801' # active case - yellow

# converter
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()   

# hide warnings
import warnings
warnings.filterwarnings('ignore')

# html embedding
from IPython.display import Javascript
from IPython.core.display import display, HTML

# %%
#hide
# importing datasets
url = 'https://raw.githubusercontent.com/imdevskp/covid_19_jhu_data_web_scrap_and_cleaning/master/new/complete_data.csv'
full_table = pd.read_csv(url, 
                         parse_dates=['Date'])
full_table.head()
# Out:
#   Province/State Country/Region      Lat     Long       Date  Confirmed  \
# 0            NaN    Afghanistan  33.0000  65.0000 2020-01-22          0
# 1            NaN        Albania  41.1533  20.1683 2020-01-22          0
# 2            NaN        Algeria  28.0339   1.6596 2020-01-22          0
# 3            NaN        Andorra  42.5063   1.5218 2020-01-22          0
# 4            NaN         Angola -11.2027  17.8739 2020-01-22          0
#
#    Deaths
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
#hide
# cases 
cases = ['Confirmed', 'Deaths']

# replacing Mainland china with just China
full_table['Country/Region'] = full_table['Country/Region'].replace('Mainland China', 'China')

# filling missing values 
full_table[['Province/State']] = full_table[['Province/State']].fillna('')
full_table[cases] = full_table[cases].fillna(0)

# %%
#hide
# cases in the ships
ship = full_table[full_table['Province/State'].str.contains('Grand Princess')|full_table['Province/State'].str.contains('Diamond Princess cruise ship')]

# china and the row
china = full_table[full_table['Country/Region']=='China']
row = full_table[full_table['Country/Region']!='China']

# latest
full_latest = full_table[full_table['Date'] == max(full_table['Date'])].reset_index()
china_latest = full_latest[full_latest['Country/Region']=='China']
row_latest = full_latest[full_latest['Country/Region']!='China']

# latest condensed
full_latest_grouped = full_latest.groupby('Country/Region')['Confirmed', 'Deaths'].sum().reset_index()
china_latest_grouped = china_latest.groupby('Province/State')['Confirmed', 'Deaths'].sum().reset_index()
row_latest_grouped = row_latest.groupby('Country/Region')['Confirmed', 'Deaths'].sum().reset_index()

# %% [markdown]
# # World-Wide Totals

# %%
#hide
temp = full_table.groupby(['Country/Region', 'Province/State'])['Confirmed', 'Deaths'].max()
# temp.style.background_gradient(cmap='Reds')

# %%
#hide_input
temp = full_table.groupby('Date')['Confirmed', 'Deaths'].sum().reset_index()
temp = temp[temp['Date']==max(temp['Date'])].reset_index(drop=True)
temp.style.background_gradient(cmap='Pastel1')
# Out:
# <style  type="text/css" >
#     #T_8618099c_72c1_11ea_b5bc_000d3a8de3ecrow0_col1 {
#             background-color:  #fbb4ae;
#             color:  #000000;
#         }    #T_8618099c_72c1_11ea_b5bc_000d3a8de3ecrow0_col2 {
#             background-color:  #fbb4ae;
#             color:  #000000;
#         }</style><table id="T_8618099c_72c1_11ea_b5bc_000d3a8de3ec" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Date</th>        <th class="col_heading level0 col1" >Confirmed</th>        <th class="col_heading level0 col2" >Deaths</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8618099c_72c1_11ea_b5bc_000d3a8de3eclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8618099c_72c1_11ea_b5bc_000d3a8de3ecrow0_col0" class="data row0 col0" >2020-03-24 00:00:00</td>
#                         <td id="T_8618099c_72c1_11ea_b5bc_000d3a8de3ecrow0_col1" class="data row0 col1" >418678</td>
#                         <td id="T_8618099c_72c1_11ea_b5bc_000d3a8de3ecrow0_col2" class="data row0 col2" >18625</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# # Progression of Virus Over Time

# %%
#hide_input
# https://app.flourish.studio/visualisation/1571387/edit
HTML('''<div class="flourish-embed flourish-bar-chart-race" data-src="visualisation/1571387"><script src="https://public.flourish.studio/resources/embed.js"></script></div>''')
# Out:
# <div class="flourish-embed flourish-bar-chart-race" data-src="visualisation/1571387"><script src="https://public.flourish.studio/resources/embed.js"></script></div>

# %% [markdown]
# # Maps

# %%
#hide
# Confirmed

fig = px.choropleth(full_latest_grouped, locations="Country/Region", 
                    locationmode='country names', color="Confirmed", 
                    hover_name="Country/Region", range_color=[1,7000], 
                    color_continuous_scale="aggrnyl", 
                    title='Countries with Confirmed Cases')
fig.update(layout_coloraxis_showscale=False)
fig.write_image('covid-eda-1-1.png')

# %%
#hide
# Deaths

fig = px.choropleth(full_latest_grouped[full_latest_grouped['Deaths']>0], 
                    locations="Country/Region", locationmode='country names',
                    color="Deaths", hover_name="Country/Region", 
                    range_color=[1,50], color_continuous_scale="agsunset",
                    title='Countries with Deaths Reported')
fig.update(layout_coloraxis_showscale=False)
fig.write_image('covid-eda-1-2.png')

# %% [markdown]
# ![](covid-eda-1-1.png)
# ![](covid-eda-1-2.png)

# %% [markdown]
# # Top 20 Countries

# %%
#hide
flg = full_latest_grouped
flg.head()
# Out:
#   Country/Region  Confirmed  Deaths
# 0    Afghanistan         74       1
# 1        Albania        123       5
# 2        Algeria        264      19
# 3        Andorra        164       1
# 4         Angola          3       0

# %%
#hide
fig = px.bar(flg.sort_values('Confirmed', ascending=False).head(20).sort_values('Confirmed', ascending=True), 
             x="Confirmed", y="Country/Region", title='Confirmed Cases', text='Confirmed', orientation='h', 
             width=700, height=700, range_x = [0, max(flg['Confirmed'])+10000])
fig.update_traces(marker_color=cnf, opacity=0.6, textposition='outside')
fig.write_image('covid-eda-4-1.png')

# %%
#hide
fig = px.bar(flg.sort_values('Deaths', ascending=False).head(20).sort_values('Deaths', ascending=True), 
             x="Deaths", y="Country/Region", title='Deaths', text='Deaths', orientation='h', 
             width=700, height=700, range_x = [0, max(flg['Deaths'])+500])
fig.update_traces(marker_color=dth, opacity=0.6, textposition='outside')
fig.write_image('covid-eda-4-2.png')

# %%
#hide
# (Only countries with more than 100 case are considered)

flg['Mortality Rate'] = round((flg['Deaths']/flg['Confirmed'])*100, 2)
temp = flg[flg['Confirmed']>100]
temp = temp.sort_values('Mortality Rate', ascending=False)

fig = px.bar(temp.sort_values('Mortality Rate', ascending=False).head(15).sort_values('Mortality Rate', ascending=True), 
             x="Mortality Rate", y="Country/Region", text='Mortality Rate', orientation='h', 
             width=700, height=600, range_x = [0, 8], title='No. of Deaths Per 100 Confirmed Case')
fig.update_traces(marker_color=act, opacity=0.6, textposition='outside')
fig.write_image('covid-eda-4-5.png')

# %% [markdown]
# ![](covid-eda-4-1.png)
# ![](covid-eda-4-2.png)
# ![](covid-eda-4-5.png)

# %% [markdown]
# # Composition of Cases

# %%
#hide_input
fig = px.treemap(full_latest.sort_values(by='Confirmed', ascending=False).reset_index(drop=True), 
                 path=["Country/Region", "Province/State"], values="Confirmed", height=700,
                 title='Number of Confirmed Cases',
                 color_discrete_sequence = px.colors.qualitative.Prism)
fig.data[0].textinfo = 'label+text+value'
fig.write_image('covid-eda-8-1.png')

fig = px.treemap(full_latest.sort_values(by='Deaths', ascending=False).reset_index(drop=True), 
                 path=["Country/Region", "Province/State"], values="Deaths", height=700,
                 title='Number of Deaths reported',
                 color_discrete_sequence = px.colors.qualitative.Prism)
fig.data[0].textinfo = 'label+text+value'
fig.write_image('covid-eda-8-2.png')

# %% [markdown]
# ![](covid-eda-8-1.png)
# ![](covid-eda-8-2.png)

# %% [markdown]
# # Epidemic Span

# %% [markdown]
# Note : In the graph, last day is shown as one day after the last time a new confirmed cases reported in the Country / Region

# %%
#hide_input
# first date
# ----------
first_date = full_table[full_table['Confirmed']>0]
first_date = first_date.groupby('Country/Region')['Date'].agg(['min']).reset_index()
# first_date.head()
from datetime import timedelta  
# last date
# ---------
last_date = full_table.groupby(['Country/Region', 'Date', ])['Confirmed', 'Deaths']
last_date = last_date.sum().diff().reset_index()

mask = last_date['Country/Region'] != last_date['Country/Region'].shift(1)
last_date.loc[mask, 'Confirmed'] = np.nan
last_date.loc[mask, 'Deaths'] = np.nan

last_date = last_date[last_date['Confirmed']>0]
last_date = last_date.groupby('Country/Region')['Date'].agg(['max']).reset_index()
# last_date.head()

# first_last
# ----------
first_last = pd.concat([first_date, last_date[['max']]], axis=1)

# added 1 more day, which will show the next day as the day on which last case appeared
first_last['max'] = first_last['max'] + timedelta(days=1)

# no. of days
first_last['Days'] = first_last['max'] - first_last['min']

# task column as country
first_last['Task'] = first_last['Country/Region']

# rename columns
first_last.columns = ['Country/Region', 'Start', 'Finish', 'Days', 'Task']

# sort by no. of days
first_last = first_last.sort_values('Days')
# first_last.head()

# visualization
# --------------

# produce random colors
clr = ["#"+''.join([random.choice('0123456789ABC') for j in range(6)]) for i in range(len(first_last))]

#plot
fig = ff.create_gantt(first_last, index_col='Country/Region', colors=clr, show_colorbar=False, 
                      bar_width=0.2, showgrid_x=True, showgrid_y=True, height=1600, 
                      title=('Gantt Chart'))
fig.write_image('covid-eda-9-1.png')

# %% [markdown]
# ![](covid-eda-9-1.png)

# %% [markdown]
# # China vs. Not China

# %%
#hide
# In China
temp = china.groupby('Date')['Confirmed', 'Deaths'].sum().diff()
temp = temp.reset_index()
temp = temp.melt(id_vars="Date", 
                 value_vars=['Confirmed', 'Deaths'])

fig = px.bar(temp, x="Date", y="value", color='variable', 
             title='In China',
             color_discrete_sequence=[cnf, dth, rec])
fig.update_layout(barmode='group')
fig.write_image('covid-eda-10-1.png')

#-----------------------------------------------------------------------------

# ROW
temp = row.groupby('Date')['Confirmed', 'Deaths'].sum().diff()
temp = temp.reset_index()
temp = temp.melt(id_vars="Date",
                 value_vars=['Confirmed', 'Deaths'])

fig = px.bar(temp, x="Date", y="value", color='variable', 
             title='Outside China',
             color_discrete_sequence=[cnf, dth, rec])
fig.update_layout(barmode='group')
fig.write_image('covid-eda-10-2.png')

# %%
#hide
def from_china_or_not(row):
    if row['Country/Region']=='China':
        return 'From China'
    else:
        return 'Outside China'
    
temp = full_table.copy()
temp['Region'] = temp.apply(from_china_or_not, axis=1)
temp = temp.groupby(['Region', 'Date'])['Confirmed', 'Deaths']
temp = temp.sum().diff().reset_index()
mask = temp['Region'] != temp['Region'].shift(1)
temp.loc[mask, 'Confirmed'] = np.nan
temp.loc[mask, 'Deaths'] = np.nan

fig = px.bar(temp, x='Date', y='Confirmed', color='Region', barmode='group', 
             text='Confirmed', title='Confirmed', color_discrete_sequence= [cnf, dth, rec])
fig.update_traces(textposition='outside')
fig.write_image('covid-eda-10-3.png')

fig = px.bar(temp, x='Date', y='Deaths', color='Region', barmode='group', 
             text='Confirmed', title='Deaths', color_discrete_sequence= [cnf, dth, rec])
fig.update_traces(textposition='outside')
fig.update_traces(textangle=-90)
fig.write_image('covid-eda-10-4.png')

# %%
#hide
gdf = full_table.groupby(['Date', 'Country/Region'])['Confirmed', 'Deaths'].max()
gdf = gdf.reset_index()

temp = gdf[gdf['Country/Region']=='China'].reset_index()
temp = temp.melt(id_vars='Date', value_vars=['Confirmed', 'Deaths'],
                var_name='Case', value_name='Count')
fig = px.bar(temp, x="Date", y="Count", color='Case', facet_col="Case",
            title='China', color_discrete_sequence=[cnf, dth, rec])
fig.write_image('covid-eda-10-5.png')

temp = gdf[gdf['Country/Region']!='China'].groupby('Date').sum().reset_index()
temp = temp.melt(id_vars='Date', value_vars=['Confirmed', 'Deaths'],
                var_name='Case', value_name='Count')
fig = px.bar(temp, x="Date", y="Count", color='Case', facet_col="Case",
             title='ROW', color_discrete_sequence=[cnf, dth, rec])
fig.write_image('covid-eda-10-6.png')

# %% [markdown]
# ![](covid-eda-10-1.png)
# ![](covid-eda-10-2.png)
# ![](covid-eda-10-3.png)
# ![](covid-eda-10-4.png)
# ![](covid-eda-10-5.png)

# %% [markdown]
# # Data By Country

# %% [markdown]
# ### Top 50 Countries By Confirmed Cases

# %%
#hide_input
temp_f = full_latest_grouped.sort_values(by='Confirmed', ascending=False).head(50)
temp_f = temp_f.reset_index(drop=True)
temp_f.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow0_col2 {
#             background-color:  #fb7050;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow0_col3 {
#             background-color:  #fc8767;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow1_col1 {
#             background-color:  #ad1117;
#             color:  #f1f1f1;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow1_col2 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow1_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow2_col1 {
#             background-color:  #e53228;
#             color:  #f1f1f1;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow2_col2 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow2_col3 {
#             background-color:  #fedecf;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow3_col1 {
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow3_col2 {
#             background-color:  #fc8666;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow3_col3 {
#             background-color:  #d52221;
#             color:  #f1f1f1;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow4_col1 {
#             background-color:  #fc8a6a;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow4_col2 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow4_col3 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow5_col1 {
#             background-color:  #fcab8f;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow5_col2 {
#             background-color:  #fcb095;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow5_col3 {
#             background-color:  #be151a;
#             color:  #f1f1f1;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow6_col1 {
#             background-color:  #fcb398;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow6_col2 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow6_col3 {
#             background-color:  #fb6c4c;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow7_col1 {
#             background-color:  #fee2d5;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow7_col2 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow7_col3 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow8_col1 {
#             background-color:  #fee3d7;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow8_col2 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow8_col3 {
#             background-color:  #fedecf;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow9_col1 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow9_col2 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow9_col3 {
#             background-color:  #f96044;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow10_col1 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow10_col2 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow10_col3 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow11_col1 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow11_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow11_col3 {
#             background-color:  #ffece4;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow12_col1 {
#             background-color:  #ffede5;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow12_col2 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow12_col3 {
#             background-color:  #fcae92;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow13_col1 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow13_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow13_col3 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow14_col1 {
#             background-color:  #fff0e9;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow14_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow14_col3 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow15_col1 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow15_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow15_col3 {
#             background-color:  #fedbcc;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow16_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow16_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow16_col3 {
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow17_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow17_col2 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow17_col3 {
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow18_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow18_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow18_col3 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow19_col1 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow19_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f432b64_72c1_11ea_b5bc_000d3a8de3ecrow19_col3 {
#             background-color:  #fff2ec;

# %% [markdown]
# ### Top 25 Countries By Deaths Reported

# %%
#hide_input
temp_flg = temp_f[temp_f['Deaths']>0][['Country/Region', 'Deaths']].head(25)
temp_flg.sort_values('Deaths', ascending=False).reset_index(drop=True).style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow1_col1 {
#             background-color:  #fb7050;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow2_col1 {
#             background-color:  #fc8666;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow3_col1 {
#             background-color:  #fcb095;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow4_col1 {
#             background-color:  #fdd5c4;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow5_col1 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow6_col1 {
#             background-color:  #ffebe2;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow7_col1 {
#             background-color:  #ffeee7;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow8_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow9_col1 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow10_col1 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow11_col1 {
#             background-color:  #fff2ec;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow12_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow13_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow14_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow15_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow16_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow17_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow18_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow19_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow20_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow21_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow22_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow23_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow24_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ec" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Country/Region</th>        <th class="col_heading level0 col1" >Deaths</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3eclevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow0_col0" class="data row0 col0" >Italy</td>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow0_col1" class="data row0 col1" >6820</td>
#             </tr>
#             <tr>
#                         <th id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3eclevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow1_col0" class="data row1 col0" >China</td>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow1_col1" class="data row1 col1" >3281</td>
#             </tr>
#             <tr>
#                         <th id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3eclevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow2_col0" class="data row2 col0" >Spain</td>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow2_col1" class="data row2 col1" >2808</td>
#             </tr>
#             <tr>
#                         <th id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3eclevel0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow3_col0" class="data row3 col0" >Iran</td>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow3_col1" class="data row3 col1" >1934</td>
#             </tr>
#             <tr>
#                         <th id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3eclevel0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow4_col0" class="data row4 col0" >France</td>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow4_col1" class="data row4 col1" >1102</td>
#             </tr>
#             <tr>
#                         <th id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3eclevel0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow5_col0" class="data row5 col0" >US</td>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow5_col1" class="data row5 col1" >706</td>
#             </tr>
#             <tr>
#                         <th id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3eclevel0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow6_col0" class="data row6 col0" >United Kingdom</td>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow6_col1" class="data row6 col1" >423</td>
#             </tr>
#             <tr>
#                         <th id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3eclevel0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow7_col0" class="data row7 col0" >Netherlands</td>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow7_col1" class="data row7 col1" >277</td>
#             </tr>
#             <tr>
#                         <th id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3eclevel0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow8_col0" class="data row8 col0" >Germany</td>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow8_col1" class="data row8 col1" >157</td>
#             </tr>
#             <tr>
#                         <th id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3eclevel0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow9_col0" class="data row9 col0" >Belgium</td>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow9_col1" class="data row9 col1" >122</td>
#             </tr>
#             <tr>
#                         <th id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3eclevel0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow10_col0" class="data row10 col0" >Switzerland</td>
#                         <td id="T_8f432b65_72c1_11ea_b5bc_000d3a8de3ecrow10_col1" class="data row10 col1" >122</td>
#             </tr>
#             <tr>
#                         <th id="T_8f432b65_72c1_11ea

# %% [markdown]
# ## Top 25 Chinese Provinces By Confirmed Cases

# %%
#hide_input
temp_f = china_latest_grouped[['Province/State', 'Confirmed', 'Deaths']]
temp_f = temp_f.sort_values(by='Confirmed', ascending=False)
temp_f = temp_f.reset_index(drop=True)
temp_f.style.background_gradient(cmap='Pastel1_r')
# Out:
# <style  type="text/css" >
#     #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow0_col1 {
#             background-color:  #fbb4ae;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow0_col2 {
#             background-color:  #fbb4ae;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow1_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow1_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow2_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow2_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow3_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow3_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow4_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow4_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow5_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow5_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow6_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow6_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow7_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow7_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow8_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow8_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow9_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow9_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow10_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow10_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow11_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow11_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow12_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow12_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow13_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow13_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow14_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow14_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow15_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow15_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow16_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow16_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow17_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow17_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow18_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow18_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow19_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow19_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow20_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow20_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow21_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow21_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow22_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow22_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow23_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow23_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow24_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow24_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow25_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow25_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow26_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow26_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow27_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow27_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow28_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow28_col2 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow29_col1 {
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }    #T_8f432b66_72c1_11ea_b5bc_000d3a8de3ecrow29_col2 {
#             background-color:  #

# %% [markdown]
# # Related Work

# %% [markdown]
# 1. https://www.kaggle.com/imdevskp/mers-outbreak-analysis
# 2. https://www.kaggle.com/imdevskp/sars-2003-outbreak-analysis
# 3. https://www.kaggle.com/imdevskp/western-africa-ebola-outbreak-analysis
